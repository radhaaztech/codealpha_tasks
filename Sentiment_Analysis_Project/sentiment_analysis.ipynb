# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load Dataset
df = pd.read_csv("Data/IMDB Dataset.csv")

# Display first 5 rows
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  str
#  1   sentiment  50000 non-null  str
# dtypes: str(2)
# memory usage: 781.4 KB

# %%
df.shape
# Out:
# (50000, 2)

# %%
df.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# positive    25000
# negative    25000
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,4))

sns.countplot(x='sentiment', data=df)

plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Count')

plt.show()

# %%
df['review_length'] = df['review'].apply(len)

df['review_length'].describe()
# Out:
# count    50000.000000
# mean      1309.431020
# std        989.728014
# min         32.000000
# 25%        699.000000
# 50%        970.000000
# 75%       1590.250000
# max      13704.000000
# Name: review_length, dtype: float64

# %%
plt.figure(figsize=(8,5))

plt.hist(df['review_length'], bins=30)

plt.title('Review Length Distribution')
plt.xlabel('Review Length')
plt.ylabel('Frequency')

plt.show()

# %%
sns.boxplot(x='sentiment', y='review_length', data=df)

plt.title('Review Length by Sentiment')

plt.show()

# %%
# Average review length by sentiment

df.groupby('sentiment')['review_length'].mean()
# Out:
# sentiment
# negative    1294.06436
# positive    1324.79768
# Name: review_length, dtype: float64

# %%
plt.figure(figsize=(6,6))

df['sentiment'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%'
)

plt.title("Sentiment Percentage")
plt.ylabel("")
plt.show()

# %%
# Most common words

from collections import Counter

all_words = " ".join(df['review']).lower().split()

common_words = Counter(all_words).most_common(10)

common_words
# Out:
# [('the', 638861),
#  ('a', 316615),
#  ('and', 313637),
#  ('of', 286661),
#  ('to', 264573),
#  ('is', 204876),
#  ('in', 179807),
#  ('i', 141587),
#  ('this', 138483),
#  ('that', 130140)]

# %%
words = [word[0] for word in common_words]
counts = [word[1] for word in common_words]

plt.figure(figsize=(10,5))

sns.barplot(x=counts, y=words)

plt.title("Top 10 Most Common Words")
plt.xlabel("Count")
plt.ylabel("Words")

plt.show()

# %% [markdown]
# # Sentiment Analysis Project
#
# ## Objective
#
# The objective of this project is to analyze IMDb movie reviews and understand the distribution of positive and negative sentiments using Python, Pandas, Matplotlib, and Seaborn.

# %% [markdown]
# ## Key Findings
#
# - Dataset contains 50,000 movie reviews.
# - No missing values were found.
# - Positive Reviews: 25,000
# - Negative Reviews: 25,000
# - The dataset is perfectly balanced.
# - Positive reviews are slightly longer on average than negative reviews.
# - Most reviews contain between 500 and 2000 characters.

# %% [markdown]
# ## Conclusion
#
# This analysis shows that the IMDb dataset is balanced and suitable for sentiment analysis tasks. The review length distribution indicates that most reviews are of moderate size, and positive reviews tend to be slightly longer than negative reviews. The project demonstrates data exploration and visualization techniques using Python.
